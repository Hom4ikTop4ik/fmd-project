# %%
import data_loader

import torch
import torch.nn as nn

import numpy as np

import random
import normalizer
from PIL import Image, ImageDraw, ImageFont

import cv2

import models
import modelutils

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))




train = data_loader.load("I:/NSU/CV/tests/torch/data/train/coords",
                         "I:/NSU/CV/tests/torch/data/train/images", 
                        firstn = 10000, batchSize = 16, shuffle = True, 
                        displace = True, size = 400, show = False)



scaler = normalizer.MinMaxNormalizer()
scaler.fit([y for _, y in train])

print("Number of batches:", len(train))
for x, y in train:
   print(x.shape, y.shape)
 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("devise is: ", device)
# Out:
# condcords14619_3d.txt dataimg14619.jpeg batch 1 from 625.0
# 400
# 0.78125 0.15625 0.1640625
# condcords14416_3d.txt dataimg14416.jpeg batch 1 from 625.0
# 400
# 0.78125 0.134765625 0.072265625
# condcords17759_3d.txt dataimg17759.jpeg batch 1 from 625.0
# 400
# 0.78125 0.197265625 0.150390625
# condcords17895_3d.txt dataimg17895.jpeg batch 1 from 625.0
# 400
# 0.78125 0.125 0.10546875
# condcords14937_3d.txt dataimg14937.jpeg batch 1 from 625.0
# 400
# 0.78125 0.158203125 0.078125
# condcords13693_3d.txt dataimg13693.jpeg batch 1 from 625.0
# 400
# 0.78125 0.150390625 0.146484375
# condcords06510_3d.txt dataimg06510.jpeg batch 1 from 625.0
# 400
# 0.78125 0.208984375 0.046875
# condcords26385_3d.txt dataimg26385.jpeg batch 1 from 625.0
# 400
# 0.78125 0.1875 0.12890625
# condcords26014_3d.txt dataimg26014.jpeg batch 1 from 625.0
# 400
# 0.78125 0.16015625 0.05078125
# condcords04668_3d.txt dataimg04668.jpeg batch 1 from 625.0
# 400
# 0.78125 0.1796875 0.033203125
# condcords13347_3d.txt dataimg13347.jpeg batch 1 from 625.0
# 400
# 0.78125 0.171875 0.1171875
# condcords25750_3d.txt dataimg25750.jpeg batch 1 from 625.0
# 400
# 0.78125 0.14453125 0.01171875
# condcords18567_3d.txt dataimg18567.jpeg batch 1 from 625.0
# 400
# 0.78125 0.115234375 0.130859375
# condcords12187_3d.txt dataimg12187.jpeg batch 1 from 625.0
# 400
# 0.78125 0.134765625 0.103515625
# condcords11614_3d.txt dataimg11614.jpeg batch 1 from 625.0
# 400
# 0.78125 0.208984375 0.0078125
# condcords09675_3d.txt dataimg09675.jpeg batch 1 from 625.0
# 400
# 0.78125 0.125 0.01171875
# condcords08974_3d.txt dataimg08974.jpeg batch 2 from 625.0
# 400
# 0.78125 0.203125 0.21484375
# condcords07656_3d.txt dataimg07656.jpeg batch 2 from 625.0
# 400
# 0.78125 0.205078125 0.05078125
# condcords03587_3d.txt dataimg03587.jpeg batch 2 from 625.0
# 400
# 0.78125 0.1171875 0.166015625
# condcords08234_3d.txt dataimg08234.jpeg batch 2 from 625.0
# 400
# 0.78125 0.1484375 0.076171875
# condcords23352_3d.txt dataimg23352.jpeg batch 2 from 625.0
# 400
# 0.78125 0.203125 0.138671875
# condcords18425_3d.txt dataimg18425.jpeg batch 2 from 625.0
# 400
# 0.78125 0.173828125 0.048828125
# condcords23572_3d.txt dataimg23572.jpeg batch 2 from 625.0
# 400
# 0.78125 0.13671875 0.044921875
# condcords20703_3d.txt dataimg20703.jpeg batch 2 from 625.0
# 400
# 0.78125 0.15625 0.09375
# condcords19383_3d.txt dataimg19383.jpeg batch 2 from 625.0
# 400
# 0.78125 0.158203125 0.1015625
# condcords24178_3d.txt dataimg24178.jpeg batch 2 from 625.0
# 400
# 0.78125 0.140625 0.140625
# condcords14330_3d.txt dataimg14330.jpeg batch 2 from 625.0
# 400
# 0.78125 0.138671875 0.048828125
# condcords16743_3d.txt dataimg16743.jpeg batch 2 from 625.0
# 400
# 0.78125 0.109375 0.1015625
# condcords07900_3d.txt dataimg07900.jpeg batch 2 from 625.0
# 400
# 0.78125 0.154296875 0.064453125
# condcords13045_3d.txt dataimg13045.jpeg batch 2 from 625.0
# 400
# 0.78125 0.20703125 0.20703125
# condcords22887_3d.txt dataimg22887.jpeg batch 2 from 625.0
# 400
# 0.78125 0.20703125 0.17578125
# condcords25121_3d.txt dataimg25121.jpeg batch 2 from 625.0
# 400
# 0.78125 0.216796875 0.0859375
# condcords19672_3d.txt dataimg19672.jpeg batch 3 from 625.0
# 400
# 0.78125 0.1875 0.05078125
# condcords25062_3d.txt dataimg25062.jpeg batch 3 from 625.0
# 400
# 0.78125 0.12890625 0.017578125
# condcords11043_3d.txt dataimg11043.jpeg batch 3 from 625.0
# 400
# 0.78125 0.1484375 0.02734375
# condcords20841_3d.txt dataimg20841.jpeg batch 3 from 625.0
# 400
# 0.78125 0.2109375 0.033203125
# condcords10504_3d.txt dataimg10504.jpeg batch 3 from 625.0
# 400
# 0.78125 0.181640625 0.052734375
# condcords21679_3d.txt dataimg21679.jpeg batch 3 from 625.0
# 400
# 0.78125 0.14453125 0.078125
# condcords19272_3d.txt dataimg19272.jpeg batch 3 from 625.0
# 400
# 0.78125 0.146484375 0.064453125
# condcords07600_3d.txt dataimg07600.jpeg batch 3 from 625.0
# 400
# 0.78125 0.14453125 0.154296875
# condcords19082_3d.txt dataimg19082.jpeg batch 3 from 625.0
# 400
# 0.78125 0.111328125 0.11328125
# condcords19784_3d.txt dataimg19784.jpeg batch 3 from 625.0
# 400
# 0.78125 0.193359375 0.181640625
# condcords15638_3d.txt dataimg15638.jpeg batch 3 from 625.0
# 400
# 0.78125 0.111328125 0.087890625
# condcords10446_3d.txt dataimg10446.jpeg batch 3 from 625.0
# 400
# 0.78125 0.12890625 0.146484375
# condcords20131_3d.txt dataimg20131.jpeg batch 3 from 625.0
# 400
# 0.78125 0.205078125 0.2109375
# condcords13166_3d.txt dataimg13166.jpeg batch 3 from 625.0
# 400
# 0.78125 0.193359375 0.052734375
# condcords21391_3d.txt dataimg21391.jpeg batch 3 from 625.0
# 400
# 0.78125 0.125 0.166015625
# condcords08259_3d.txt dataimg08259.jpeg batch 3 from 625.0
# 400
# 0.78125 0.16015625 0.0234375
# condcords24715_3d.txt dataimg24715.jpeg batch 4 from 625.0
# 400
# 0.78125 0.2109375 0.1796875
# condcords10817_3d.txt dataimg10817.jpeg batch 4 from 625.0
# 400
# 0.78125 0.111328125 0.060546875
# condcords25689_3d.txt dataimg25689.jpeg batch 4 from 625.0
# 400
# 0.78125 0.173828125 0.212890625
# condcords19988_3d.txt dataimg19988.jpeg batch 4 from 625.0
# 400
# 0.78125 0.119140625 0.169921875
# condcords25642_3d.txt dataimg25642.jpeg batch 4 from 625.0
# 400
# 0.78125 0.16796875 0.1328125
# condcords16020_3d.txt dataimg16020.jpeg batch 4 from 625.0
# 400
# 0.78125 0.2109375 0.029296875
# condcords26183_3d.txt dataimg26183.jpeg batch 4 from 625.0
# 400
# 0.78125 0.150390625 0.099609375
# condcords26041_3d.txt dataimg26041.jpeg batch 4 from 625.0
# 400
# 0.78125 0.140625 0.13671875
# condcords01465_3d.txt dataimg01465.jpeg batch 4 from 625.0
# 400
# 0.78125 0.154296875 0.126953125
# condcords04266_3d.txt dataimg04266.jpeg batch 4 from 625.0
# 400
# 0.78125 0.154296875 0.037109375
# condcords16169_3d.txt dataimg16169.jpeg batch 4 from 625.0
# 400
# 0.78125 0.21484375 0.1875
# condcords05829_3d.txt dataimg05829.jpeg batch 4 from 625.0
# 400
# 0.78125 0.162109375 0.208984375
# condcords02333_3d.txt dataimg02333.jpeg batch 4 from 625.0
# 400
# 0.78125 0.201171875 0.158203125
# condcords22054_3d.txt dataimg22054.jpeg batch 4 from 625.0
# 400
# 0.78125 0.193359375 0.189453125
# condcords01929_3d.txt dataimg01929.jpeg batch 4 from 625.0
# 400
# 0.78125 0.16015625 0.033203125
# condcords11027_3d.txt dataimg11027.jpeg batch 4 from 625.0
# 400
# 0.78125 0.1875 0.06640625
# condcords03965_3d.txt dataimg03965.jpeg batch 5 from 625.0
# 400
# 0.78125 0.177734375 0.20703125
# condcords16586_3d.txt dataimg16586.jpeg batch 5 from 625.0
# 400
# 0.78125 0.119140625 0.02734375
# condcords07675_3d.txt dataimg07675.jpeg batch 5 from 625.0
# 400
# 0.78125 0.2109375 0.109375
# condcords17431_3d.txt dataimg17431.jpeg batch 5 from 625.0
# 400
# 0.78125 0.169921875 0.119140625
# condcords09308_3d.txt dataimg09308.jpeg batch 5 from 625.0
# 400
# 0.78125 0.109375 0.072265625
# condcords24265_3d.txt dataimg24265.jpeg batch 5 from 625.0
# 400
# 0.78125 0.19140625 0.1484375
# condcords18759_3d.txt dataimg18759.jpeg batch 5 from 625.0
# 400
# 0.78125 0.130859375 0.046875
# condcords25577_3d.txt dataimg25577.jpeg batch 5 from 625.0
# 400
# 0.78125 0.109375 0.025390625
# condcords19327_3d.txt dataimg19327.jpeg batch 5 from 625.0
# 400
# 0.78125 0.134765625 0.03515625
# condcords09168_3d.txt dataimg09168.jpeg batch 5 from 625.0
# 400
# 0.78125 0.15234375 0.056640625
# condcords20301_3d.txt dataimg20301.jpeg batch 5 from 625.0
# 400
# 0.78125 0.111328125 0.154296875
# condcords07414_3d.txt dataimg07414.jpeg batch 5 from 625.0
# 400
# 0.78125 0.14453125 0.150390625
# condcords02209_3d.txt dataimg02209.jpeg batch 5 from 625.0
# 400
# 0.78125 0.140625 0.013671875
# condcords07168_3d.txt dataimg07168.jpeg batch 5 from 625.0
# 400
# 0.78125 0.185546875 0.044921875
# condcords19378_3d.txt dataimg19378.jpeg batch 5 from 625.0
# 400
# 0.78125 0.146484375 0.041015625
# condcords00974_3d.txt dataimg00974.jpeg batch 5 from 625.0
# 400
# 0.78125 0.138671875 0.125
# condcords08684_3d.txt dataimg08684.jpeg batch 6 from 625.0
# 400
# 0.78125 0.169921875 0.05078125
# condcords02167_3d.txt dataimg02167.jpeg batch 6 from 625.0
# 400
# 0.78125 0.140625 0.11328125
# condcords02444_3d.txt dataimg02444.jpeg batch 6 from 625.0
# 400
# 0.78125 0.126953125 0.119140625
# condcords01628_3d.txt dataimg01628.jpeg batch 6 from 625.0
# 400
# 0.78125 0.21875 0.03515625
# condcords18416_3d.txt dataimg18416.jpeg batch 6 from 625.0
# 400
# 0.78125 0.146484375 0.119140625
# condcords22816_3d.txt dataimg22816.jpeg batch 6 from 625.0
# 400
# 0.78125 0.134765625 0.064453125
# condcords23053_3d.txt dataimg23053.jpeg batch 6 from 625.0
# 400
# 0.78125 0.177734375 0.03515625
# condcords06220_3d.txt dataimg06220.jpeg batch 6 from 625.0
# 400
# 0.78125 0.21484375 0.21484375
# condcords06409_3d.txt dataimg06409.jpeg batch 6 from 625.0
# 400
# 0.78125 0.16015625 0.197265625
# condcords20584_3d.txt dataimg20584.jpeg batch 6 from 625.0
# 400
# 0.78125 0.15234375 0.12109375
# condcords07093_3d.txt dataimg07093.jpeg batch 6 from 625.0
# 400
# 0.78125 0.146484375 0.087890625
# condcords23921_3d.txt dataimg23921.jpeg batch 6 from 625.0
# 400
# 0.78125 0.1171875 0.119140625
# condcords05701_3d.txt dataimg05701.jpeg batch 6 from 625.0
# 400
# 0.78125 0.18359375 0.0390625
# condcords08761_3d.txt dataimg08761.jpeg batch 6 from 625.0
# 400
# 0.78125 0.111328125 0.025390625
# condcords06936_3d.txt dataimg06936.jpeg batch 6 from 625.0
# 400
# 0.78125 0.216796875 0.150390625
# condcords05426_3d.txt dataimg05426.jpeg batch 6 from 625.0
# 400
# 0.78125 0.181640625 0.083984375
# condcords06178_3d.txt dataimg06178.jpeg batch 7 from 625.0
# 400
# 0.78125 0.15625 0.02734375
# condcords00446_3d.txt dataimg00446.jpeg batch 7 from 625.0
# 400
# 0.78125 0.1640625 0.05078125
# condcords01310_3d.txt dataimg01310.jpeg batch 7 from 625.0
# 400
# 0.78125 0.173828125 0.048828125
# condcords16562_3d.txt dataimg16562.jpeg batch 7 from 625.0
# 400
# 0.78125 0.123046875 0.1640625
# condcords25887_3d.txt dataimg25887.jpeg batch 7 from 625.0
# 400
# 0.78125 0.16796875 0.150390625
# condcords26079_3d.txt dataimg26079.jpeg batch 7 from 625.0
# 400
# 0.78125 0.138671875 0.158203125
# condcords16811_3d.txt dataimg16811.jpeg batch 7 from 625.0
# 400
# 0.78125 0.2109375 0.0234375
# condcords11414_3d.txt dataimg11414.jpeg batch 7 from 625.0
# 400
# 0.78125 0.162109375 0.154296875
# condcords25848_3d.txt dataimg25848.jpeg batch 7 from 625.0
# 400
# 0.78125 0.1953125 0.1328125
# condcords14600_3d.txt dataimg14600.jpeg batch 7 from 625.0
# 400
# 0.78125 0.212890625 0.056640625
# condcords22563_3d.txt dataimg22563.jpeg batch 7 from 625.0
# 400
# 0.78125 0.193359375 0.02734375
# condcords05754_3d.txt dataimg05754.jpeg batch 7 from 625.0
# 400
# 0.78125 0.19140625 0.048828125
# condcords24183_3d.txt dataimg24183.jpeg batch 7 from 625.0
# 400
# 0.78125 0.12890625 0.17578125
# condcords08283_3d.txt dataimg08283.jpeg batch 7 from 625.0
# 400
# 0.78125 0.1328125 0.1328125
# condcords13113_3d.txt dataimg13113.jpeg batch 7 from 625.0
# 400
# 0.78125 0.177734375 0.09375
# condcords05721_3d.txt dataimg05721.jpeg batch 7 from 625.0
# 400
# 0.78125 0.21484375 0.138671875
# condcords26526_3d.txt dataimg26526.jpeg batch 8 from 625.0
# 400
# 0.78125 0.11328125 0.1171875
# condcords18997_3d.txt dataimg18997.jpeg batch 8 from 625.0
# 400
# 0.78125 0.16796875 0.181640625
# condcords21066_3d.txt dataimg21066.jpeg batch 8 from 625.0
# 400
# 0.78125 0.1796875 0.056640625
# condcords12884_3d.txt dataimg12884.jpeg batch 8 from 625.0
# 400
# 0.78125 0.14453125 0.1875
# condcords09371_3d.txt dataimg09371.jpeg batch 8 from 625.0
# 400
# 0.78125 0.18359375 0.21875
# condcords17003_3d.txt dataimg17003.jpeg batch 8 from 625.0
# 400
# 0.78125 0.212890625 0.169921875
# condcords07662_3d.txt dataimg07662.jpeg batch 8 from 625.0
# 400
# 0.78125 0.123046875 0.0703125
# condcords25662_3d.txt dataimg25662.jpeg batch 8 from 625.0
# 400
# 0.78125 0.125 0.03125
# condcords25444_3d.txt dataimg25444.jpeg batch 8 from 625.0
# 400
# 0.78125 0.134765625 0.041015625
# condcords09884_3d.txt dataimg09884.jpeg batch 8 from 625.0
# 400
# 0.78125 0.1953125 0.18359375
# condcords00326_3d.txt dataimg00326.jpeg batch 8 from 625.0
# 400
# 0.78125 0.189453125 0.189453125
# condcords22564_3d.txt dataimg22564.jpeg batch 8 from 625.0
# 400
# 0.78125 0.154296875 0.017578125
# condcords09190_3d.txt dataimg09190.jpeg batch 8 from 625.0
# 400
# 0.78125 0.12890625 0.17578125
# condcords18183_3d.txt dataimg18183.jpeg batch 8 from 625.0
# 400
# 0.78125 0.205078125 0.06640625
# condcords02286_3d.txt dataimg02286.jpeg batch 8 from 625.0
# 400
# 0.78125 0.177734375 0.072265625
# condcords22015_3d.txt dataimg22015.jpeg batch 8 from 625.0
# 400
# 0.78125 0.16796875 0.0
# condcords04055_3d.txt dataimg04055.jpeg batch 9 from 625.0
# 400
# 0.78125 0.11328125 0.19140625
# condcords19392_3d.txt dataimg19392.jpeg batch 9 from 625.0
# 400
# 0.78125 0.16015625 0.005859375
# condcords09846_3d.txt dataimg09846.jpeg batch 9 from 625.0
# 400
# 0.78125 0.15625 0.169921875
# condcords20645_3d.txt dataimg20645.jpeg batch 9 from 625.0
# 400
# 0.78125 0.189453125 0.11328125
# condcords04801_3d.txt dataimg04801.jpeg batch 9 from 625.0
# 400
# 0.78125 0.123046875 0.12890625
# condcords18031_3d.txt dataimg18031.jpeg batch 9 from 625.0
# 400
# 0.78125 0.146484375 0.01171875
# condcords22482_3d.txt dataimg22482.jpeg batch 9 from 625.0
# 400
# 0.78125 0.130859375 0.130859375
# condcords08160_3d.txt dataimg08160.jpeg batch 9 from 625.0
# 400
# 0.78125 0.125 0.025390625
# condcords09170_3d.txt dataimg09170.jpeg batch 9 from 625.0
# 400
# 0.78125 0.1328125 0.125
# condcords00658_3d.txt dataimg00658.jpeg batch 9 from 625.0
# 400
# 0.78125 0.11328125 0.171875
# condcords21164_3d.txt dataimg21164.jpeg batch 9 from 625.0
# 400
# 0.78125 0.158203125 0.21484375
# condcords02798_3d.txt dataimg02798.jpeg batch 9 from 625.0
# 400
# 0.78125 0.16015625 0.013671875
# condcords24203_3d.txt dataimg24203.jpeg batch 9 from 625.0
# 400
# 0.78125 0.216796875 0.0859375
# condcords24680_3d.txt dataimg24680.jpeg batch 9 from 625.0
# 400
# 0.78125 0.21484375 0.095703125
# condcords18805_3d.txt dataimg18805.jpeg batch 9 from 625.0
# 400
# 0.78125 0.216796875 0.1875
# condcords10779_3d.txt dataimg10779.jpeg batch 9 from 625.0
# 400
# 0.78125 0.166015625 0.21875
# condcords08381_3d.txt dataimg08381.jpeg batch 10 from 625.0
# 400
# 0.78125 0.162109375 0.0546875
# condcords10892_3d.txt dataimg10892.jpeg batch 10 from 625.0
# 400
# 0.78125 0.130859375 0.109375
# condcords15385_3d.txt dataimg15385.jpeg batch 10 from 625.0
# 400
# 0.78125 0.1875 0.015625
# condcords02756_3d.txt dataimg02756.jpeg batch 10 from 625.0
# 400
# 0.78125 0.181640625 0.015625
# condcords21559_3d.txt dataimg21559.jpeg batch 10 from 625.0
# 400
# 0.78125 0.19140625 0.111328125
# condcords13306_3d.txt dataimg13306.jpeg batch 10 from 625.0
# 400
# 0.78125 0.18359375 0.095703125
# condcords01691_3d.txt dataimg01691.jpeg batch 10 from 625.0
# 400
# 0.78125 0.1796875 0.080078125
# condcords24882_3d.txt dataimg24882.jpeg batch 10 from 625.0
# 400
# 0.78125 0.193359375 0.056640625
# condcords16248_3d.txt dataimg16248.jpeg batch 10 from 625.0
# 400
# 0.78125 0.130859375 0.11328125
# condcords01387_3d.txt dataimg01387.jpeg batch 10 from 625.0
# 400
# 0.78125 0.21484375 0.1875
# condcords08866_3d.txt dataimg08866.jpeg batch 10 from 625.0
# 400
# 0.78125 0.17578125 0.060546875
# condcords23661_3d.txt dataimg23661.jpeg batch 10 from 625.0
# 400
# 0.78125 0.11328125 0.1328125
# condcords25355_3d.txt dataimg25355.jpeg batch 10 from 625.0
# 400
# 0.78125 0.111328125 0.08984375
# condcords04227_3d.txt dataimg04227.jpeg batch 10 from 625.0
# 400
# 0.78125 0.189453125 0.216796875
# condcords10208_3d.txt dataimg10208.jpeg batch 10 from 625.0
# 400
# 0.78125 0.154296875 0.1015625
# condcords22209_3d.txt dataimg22209.jpeg batch 10 from 625.0
# 400
# 0.78125 0.140625 0.10546875
# condcords25026_3d.txt dataimg25026.jpeg batch 11 from 625.0
# 400
# 0.78125 0.138671875 0.193359375
# condcords03406_3d.txt dataimg03406.jpeg batch 11 from 625.0
# 400
# 0.78125 0.16015625 0.00390625
# condcords24961_3d.txt dataimg24961.jpeg batch 11 from 625.0
# 400
# 0.78125 0.19140625 0.099609375
# condcords26013_3d.txt dataimg26013.jpeg batch 11 from 625.0
# 400
# 0.78125 0.16015625 0.060546875
# condcords01623_3d.txt dataimg01623.jpeg batch 11 from 625.0
# 400
# 0.78125 0.126953125 0.123046875
# condcords12239_3d.txt dataimg12239.jpeg batch 11 from 625.0
# 400
# 0.78125 0.11328125 0.087890625
# condcords06718_3d.txt dataimg06718.jpeg batch 11 from 625.0
# 400
# 0.78125 0.203125 0.181640625
# condcords22311_3d.txt dataimg22311.jpeg batch 11 from 625.0
# 400
# 0.78125 0.150390625 0.169921875
# condcords02700_3d.txt dataimg02700.jpeg batch 11 from 625.0
# 400
# 0.78125 0.130859375 0.16015625
# condcords15136_3d.txt dataimg15136.jpeg batch 11 from 625.0
# 400
# 0.78125 0.1875 0.080078125
# condcords17303_3d.txt dataimg17303.jpeg batch 11 from 625.0
# 400
# 0.78125 0.158203125 0.21875
# condcords13909_3d.txt dataimg13909.jpeg batch 11 from 625.0
# 400
# 0.78125 0.205078125 0.197265625
# condcords03169_3d.txt dataimg03169.jpeg batch 11 from 625.0
# 400
# 0.78125 0.189453125 0.091796875
# condcords12048_3d.txt dataimg12048.jpeg batch 11 from 625.0
# 400
# 0.78125 0.15234375 0.126953125
# condcords24274_3d.txt dataimg24274.jpeg batch 11 from 625.0
# 400
# 0.78125 0.13671875 0.150390625
# condcords15362_3d.txt dataimg15362.jpeg batch 11 from 625.0
# 400
# 0.78125 0.162109375 0.1796875
# condcords24800_3d.txt dataimg24800.jpeg batch 12 from 625.0
# 400
# 0.78125 0.20703125 0.21484375
# condcords18857_3d.txt dataimg18857.jpeg batch 12 from 625.0
# 400
# 0.78125 0.138671875 0.08203125
# condcords06053_3d.txt dataimg06053.jpeg batch 12 from 625.0
# 400
# 0.78125 0.1875 0.1171875
# condcords25297_3d.txt dataimg25297.jpeg batch 12 from 625.0
# 400
# 0.78125 0.123046875 0.203125
# condcords03432_3d.txt dataimg03432.jpeg batch 12 from 625.0
# 400
# 0.78125 0.12109375 0.13671875
# condcords11788_3d.txt dataimg11788.jpeg batch 12 from 625.0
# 400
# 0.78125 0.185546875 0.20703125
# condcords16853_3d.txt dataimg16853.jpeg batch 12 from 625.0
# 400
# 0.78125 0.197265625 0.060546875
# condcords12471_3d.txt dataimg12471.jpeg batch 12 from 625.0
# 400
# 0.78125 0.216796875 0.205078125
# condcords25663_3d.txt dataimg25663.jpeg batch 12 from 625.0
# 400
# 0.78125 0.16015625 0.0
# condcords00929_3d.txt dataimg00929.jpeg batch 12 from 625.0
# 400
# 0.78125 0.173828125 0.158203125
# condcords21080_3d.txt dataimg21080.jpeg batch 12 from 625.0
# 400
# 0.78125 0.197265625 0.0390625
# condcords03383_3d.txt dataimg03383.jpeg batch 12 from 625.0
# 400
# 0.78125 0.16796875 0.126953125
# condcords01550_3d.txt dataimg01550.jpeg batch 12 from 625.0
# 400
# 0.78125 0.130859375 0.044921875
# condcords06193_3d.txt dataimg06193.jpeg batch 12 from 625.0
# 400
# 0.78125 0.193359375 0.0234375
# condcords22384_3d.txt dataimg22384.jpeg batch 12 from 625.0
# 400
# 0.78125 0.1171875 0.05078125
# condcords12880_3d.txt dataimg12880.jpeg batch 12 from 625.0
# 400
# 0.78125 0.1171875 0.14453125
# condcords03281_3d.txt dataimg03281.jpeg batch 13 from 625.0
# 400
# 0.78125 0.1640625 0.00390625
# condcords01393_3d.txt dataimg01393.jpeg batch 13 from 625.0
# 400
# 0.78125 0.12109375 0.078125
# condcords00720_3d.txt dataimg00720.jpeg batch 13 from 625.0
# 400
# 0.78125 0.134765625 0.0703125
# condcords22027_3d.txt dataimg22027.jpeg batch 13 from 625.0
# 400
# 0.78125 0.181640625 0.11328125
# condcords25449_3d.txt dataimg25449.jpeg batch 13 from 625.0
# 400
# 0.78125 0.21484375 0.087890625
# condcords16670_3d.txt dataimg16670.jpeg batch 13 from 625.0
# 400
# 0.78125 0.134765625 0.109375
# condcords22169_3d.txt dataimg22169.jpeg batch 13 from 625.0
# 400
# 0.78125 0.173828125 0.01171875
# condcords22889_3d.txt dataimg22889.jpeg batch 13 from 625.0
# 400
# 0.78125 0.19921875 0.09375
# condcords01641_3d.txt dataimg01641.jpeg batch 13 from 625.0
# 400
# 0.78125 0.14453125 0.138671875
# condcords11743_3d.txt dataimg11743.jpeg batch 13 from 625.0
# 400
# 0.78125 0.123046875 0.208984375
# condcords12974_3d.txt dataimg12974.jpeg batch 13 from 625.0
# 400
# 0.78125 0.216796875 0.013671875
# condcords24963_3d.txt dataimg24963.jpeg batch 13 from 625.0
# 400
# 0.78125 0.166015625 0.11328125
# condcords17094_3d.txt dataimg17094.jpeg batch 13 from 625.0
# 400
# 0.78125 0.123046875 0.107421875
# condcords05076_3d.txt dataimg05076.jpeg batch 13 from 625.0
# 400
# 0.78125 0.1953125 0.15234375
# condcords23644_3d.txt dataimg23644.jpeg batch 13 from 625.0
# 400
# 0.78125 0.119140625 0.052734375
# condcords16814_3d.txt dataimg16814.jpeg batch 13 from 625.0
# 400
# 0.78125 0.185546875 0.0703125
# condcords13496_3d.txt dataimg13496.jpeg batch 14 from 625.0
# 400
# 0.78125 0.21875 0.134765625
# condcords07436_3d.txt dataimg07436.jpeg batch 14 from 625.0
# 400
# 0.78125 0.17578125 0.01171875
# condcords22841_3d.txt dataimg22841.jpeg batch 14 from 625.0
# 400
# 0.78125 0.1328125 0.140625
# condcords04294_3d.txt dataimg04294.jpeg batch 14 from 625.0
# 400
# 0.78125 0.201171875 0.21484375
# condcords07714_3d.txt dataimg07714.jpeg batch 14 from 625.0
# 400
# 0.78125 0.12109375 0.021484375
# condcords22955_3d.txt dataimg22955.jpeg batch 14 from 625.0
# 400
# 0.78125 0.1953125 0.162109375
# condcords26459_3d.txt dataimg26459.jpeg batch 14 from 625.0
# 400
# 0.78125 0.162109375 0.01171875
# condcords15092_3d.txt dataimg15092.jpeg batch 14 from 625.0
# 400
# 0.78125 0.115234375 0.06640625
# condcords11208_3d.txt dataimg11208.jpeg batch 14 from 625.0
# 400
# 0.78125 0.150390625 0.21875
# condcords20611_3d.txt dataimg20611.jpeg batch 14 from 625.0
# 400
# 0.78125 0.142578125 0.134765625
# condcords08523_3d.txt dataimg08523.jpeg batch 14 from 625.0
# 400
# 0.78125 0.109375 0.05078125
# condcords17658_3d.txt dataimg17658.jpeg batch 14 from 625.0
# 400
# 0.78125 0.1171875 0.181640625
# condcords11964_3d.txt dataimg11964.jpeg batch 14 from 625.0
# 400
# 0.78125 0.12109375 0.212890625
# condcords13714_3d.txt dataimg13714.jpeg batch 14 from 625.0
# 400
# 0.78125 0.212890625 0.046875
# condcords02495_3d.txt dataimg02495.jpeg batch 14 from 625.0
# 400
# 0.78125 0.130859375 0.060546875
# condcords11725_3d.txt dataimg11725.jpeg batch 14 from 625.0
# 400
# 0.78125 0.1875 0.087890625
# condcords12390_3d.txt dataimg12390.jpeg batch 15 from 625.0
# 400
# 0.78125 0.2109375 0.13671875
# condcords02453_3d.txt dataimg02453.jpeg batch 15 from 625.0
# 400
# 0.78125 0.193359375 0.099609375
# condcords02071_3d.txt dataimg02071.jpeg batch 15 from 625.0
# 400
# 0.78125 0.158203125 0.162109375
# condcords10332_3d.txt dataimg10332.jpeg batch 15 from 625.0
# 400
# 0.78125 0.1640625 0.0625
# condcords18438_3d.txt dataimg18438.jpeg batch 15 from 625.0
# 400
# 0.78125 0.16015625 0.15625
# condcords13827_3d.txt dataimg13827.jpeg batch 15 from 625.0
# 400
# 0.78125 0.1875 0.001953125
# condcords20788_3d.txt dataimg20788.jpeg batch 15 from 625.0
# 400
# 0.78125 0.18359375 0.177734375
# condcords09033_3d.txt dataimg09033.jpeg batch 15 from 625.0
# 400
# 0.78125 0.181640625 0.03515625
# condcords12798_3d.txt dataimg12798.jpeg batch 15 from 625.0
# 400
# 0.78125 0.177734375 0.001953125
# condcords23396_3d.txt dataimg23396.jpeg batch 15 from 625.0
# 400
# 0.78125 0.1328125 0.146484375
# condcords24495_3d.txt dataimg24495.jpeg batch 15 from 625.0
# 400
# 0.78125 0.18359375 0.138671875
# condcords07886_3d.txt dataimg07886.jpeg batch 15 from 625.0
# 400
# 0.78125 0.158203125 0.189453125
# condcords20182_3d.txt dataimg20182.jpeg batch 15 from 625.0
# 400
# 0.78125 0.16796875 0.150390625
# condcords06984_3d.txt dataimg06984.jpeg batch 15 from 625.0
# 400
# 0.78125 0.158203125 0.09765625
# condcords10977_3d.txt dataimg10977.jpeg batch 15 from 625.0
# 400
# 0.78125 0.126953125 0.08984375
# condcords13852_3d.txt dataimg13852.jpeg batch 15 from 625.0
# 400
# 0.78125 0.16015625 0.185546875
# condcords05005_3d.txt dataimg05005.jpeg batch 16 from 625.0
# 400
# 0.78125 0.130859375 0.05078125
# condcords12615_3d.txt dataimg12615.jpeg batch 16 from 625.0
# 400
# 0.78125 0.169921875 0.017578125
# condcords11850_3d.txt dataimg11850.jpeg batch 16 from 625.0
# 400
# 0.78125 0.154296875 0.197265625
# condcords04156_3d.txt dataimg04156.jpeg batch 16 from 625.0
# 400
# 0.78125 0.146484375 0.181640625
# condcords14485_3d.txt dataimg14485.jpeg batch 16 from 625.0
# 400
# 0.78125 0.16796875 0.111328125
# condcords23388_3d.txt dataimg23388.jpeg batch 16 from 625.0
# 400
# 0.78125 0.201171875 0.12109375
# condcords09296_3d.txt dataimg09296.jpeg batch 16 from 625.0
# 400
# 0.78125 0.21484375 0.04296875
# condcords25685_3d.txt dataimg25685.jpeg batch 16 from 625.0
# 400
# 0.78125 0.1328125 0.001953125
# condcords22029_3d.txt dataimg22029.jpeg batch 16 from 625.0
# 400
# 0.78125 0.134765625 0.11328125
# condcords15068_3d.txt dataimg15068.jpeg batch 16 from 625.0
# 400
# 0.78125 0.115234375 0.162109375
# condcords07334_3d.txt dataimg07334.jpeg batch 16 from 625.0
# 400
# 0.78125 0.111328125 0.169921875
# condcords04983_3d.txt dataimg04983.jpeg batch 16 from 625.0
# 400
# 0.78125 0.154296875 0.068359375
# condcords00896_3d.txt dataimg00896.jpeg batch 16 from 625.0
# 400
# 0.78125 0.162109375 0.1328125
# condcords04762_3d.txt dataimg04762.jpeg batch 16 from 625.0
# 400
# 0.78125 0.125 0.111328125
# condcords02696_3d.txt dataimg02696.jpeg batch 16 from 625.0
# 400
# 0.78125 0.1171875 0.076171875
# condcords02142_3d.txt dataimg02142.jpeg batch 16 from 625.0
# 400
# 0.78125 0.193359375 0.05078125
# condcords23869_3d.txt dataimg23869.jpeg batch 17 from 625.0
# 400
# 0.78125 0.154296875 0.150390625
# condcords14735_3d.txt dataimg14735.jpeg batch 17 from 625.0
# 400
# 0.78125 0.208984375 0.025390625
# condcords04264_3d.txt dataimg04264.jpeg batch 17 from 625.0
# 400
# 0.78125 0.154296875 0.21484375
# condcords05111_3d.txt dataimg05111.jpeg batch 17 from 625.0
# 400
# 0.78125 0.15234375 0.05078125
# condcords20662_3d.txt dataimg20662.jpeg batch 17 from 625.0
# 400
# 0.78125 0.189453125 0.185546875
# condcords02678_3d.txt dataimg02678.jpeg batch 17 from 625.0
# 400
# 0.78125 0.1484375 0.1953125
# condcords05153_3d.txt dataimg05153.jpeg batch 17 from 625.0
# 400
# 0.78125 0.15234375 0.095703125
# condcords13675_3d.txt dataimg13675.jpeg batch 17 from 625.0
# 400
# 0.78125 0.109375 0.0703125
# condcords21281_3d.txt dataimg21281.jpeg batch 17 from 625.0
# 400
# 0.78125 0.1640625 0.109375
# condcords00813_3d.txt dataimg00813.jpeg batch 17 from 625.0
# 400
# 0.78125 0.126953125 0.125
# condcords16388_3d.txt dataimg16388.jpeg batch 17 from 625.0
# 400
# 0.78125 0.142578125 0.044921875
# condcords11317_3d.txt dataimg11317.jpeg batch 17 from 625.0
# 400
# 0.78125 0.150390625 0.09375
# condcords14740_3d.txt dataimg14740.jpeg batch 17 from 625.0
# 400
# 0.78125 0.16015625 0.078125
# condcords07363_3d.txt dataimg07363.jpeg batch 17 from 625.0
# 400
# 0.78125 0.126953125 0.205078125
# condcords09049_3d.txt dataimg09049.jpeg batch 17 from 625.0
# 400
# 0.78125 0.17578125 0.0234375
# condcords08300_3d.txt dataimg08300.jpeg batch 17 from 625.0
# 400
# 0.78125 0.205078125 0.205078125
# condcords23820_3d.txt dataimg23820.jpeg batch 18 from 625.0
# 400
# 0.78125 0.142578125 0.1875
# condcords25332_3d.txt dataimg25332.jpeg batch 18 from 625.0
# 400
# 0.78125 0.193359375 0.068359375
# condcords06639_3d.txt dataimg06639.jpeg batch 18 from 625.0
# 400
# 0.78125 0.1328125 0.0859375
# condcords06895_3d.txt dataimg06895.jpeg batch 18 from 625.0
# 400
# 0.78125 0.1640625 0.015625
# condcords19314_3d.txt dataimg19314.jpeg batch 18 from 625.0
# 400
# 0.78125 0.11328125 0.052734375
# condcords23007_3d.txt dataimg23007.jpeg batch 18 from 625.0
# 400
# 0.78125 0.15234375 0.060546875
# condcords14371_3d.txt dataimg14371.jpeg batch 18 from 625.0
# 400
# 0.78125 0.177734375 0.16796875
# condcords08334_3d.txt dataimg08334.jpeg batch 18 from 625.0
# 400
# 0.78125 0.177734375 0.115234375
# condcords03337_3d.txt dataimg03337.jpeg batch 18 from 625.0
# 400
# 0.78125 0.109375 0.103515625
# condcords26616_3d.txt dataimg26616.jpeg batch 18 from 625.0
# 400
# 0.78125 0.177734375 0.01953125
# condcords01838_3d.txt dataimg01838.jpeg batch 18 from 625.0
# 400
# 0.78125 0.126953125 0.171875
# condcords25037_3d.txt dataimg25037.jpeg batch 18 from 625.0
# 400
# 0.78125 0.146484375 0.212890625
# condcords24461_3d.txt dataimg24461.jpeg batch 18 from 625.0
# 400
# 0.78125 0.142578125 0.037109375
# condcords03562_3d.txt dataimg03562.jpeg batch 18 from 625.0
# 400
# 0.78125 0.130859375 0.177734375
# condcords07442_3d.txt dataimg07442.jpeg batch 18 from 625.0
# 400
# 0.78125 0.13671875 0.201171875
# condcords15287_3d.txt dataimg15287.jpeg batch 18 from 625.0
# 400
# 0.78125 0.1875 0.013671875
# condcords03291_3d.txt dataimg03291.jpeg batch 19 from 625.0
# 400
# 0.78125 0.1328125 0.001953125
# condcords02022_3d.txt dataimg02022.jpeg batch 19 from 625.0
# 400
# 0.78125 0.16796875 0.03125
# condcords08922_3d.txt dataimg08922.jpeg batch 19 from 625.0
# 400
# 0.78125 0.162109375 0.154296875
# condcords25655_3d.txt dataimg25655.jpeg batch 19 from 625.0
# 400
# 0.78125 0.154296875 0.021484375
# condcords22760_3d.txt dataimg22760.jpeg batch 19 from 625.0
# 400
# 0.78125 0.189453125 0.140625
# condcords13161_3d.txt dataimg13161.jpeg batch 19 from 625.0
# 400
# 0.78125 0.134765625 0.005859375
# condcords16368_3d.txt dataimg16368.jpeg batch 19 from 625.0
# 400
# 0.78125 0.1953125 0.130859375
# condcords24671_3d.txt dataimg24671.jpeg batch 19 from 625.0
# 400
# 0.78125 0.126953125 0.013671875
# condcords26012_3d.txt dataimg26012.jpeg batch 19 from 625.0
# 400
# 0.78125 0.177734375 0.208984375
# condcords12518_3d.txt dataimg12518.jpeg batch 19 from 625.0
# 400
# 0.78125 0.19140625 0.01953125
# condcords10959_3d.txt dataimg10959.jpeg batch 19 from 625.0
# 400
# 0.78125 0.203125 0.005859375
# condcords05919_3d.txt dataimg05919.jpeg batch 19 from 625.0
# 400
# 0.78125 0.21484375 0.005859375
# condcords15934_3d.txt dataimg15934.jpeg batch 19 from 625.0
# 400
# 0.78125 0.14453125 0.107421875
# condcords25643_3d.txt dataimg25643.jpeg batch 19 from 625.0
# 400
# 0.78125 0.2109375 0.17578125
# condcords12252_3d.txt dataimg12252.jpeg batch 19 from 625.0
# 400
# 0.78125 0.171875 0.087890625
# condcords02380_3d.txt dataimg02380.jpeg batch 19 from 625.0
# 400
# 0.78125 0.162109375 0.2109375
# condcords06029_3d.txt dataimg06029.jpeg batch 20 from 625.0
# 400
# 0.78125 0.1171875 0.15234375
# condcords14292_3d.txt dataimg14292.jpeg batch 20 from 625.0
# 400
# 0.78125 0.138671875 0.005859375
# condcords21634_3d.txt dataimg21634.jpeg batch 20 from 625.0
# 400
# 0.78125 0.11328125 0.138671875
# condcords02836_3d.txt dataimg02836.jpeg batch 20 from 625.0
# 400
# 0.78125 0.123046875 0.216796875
# condcords13826_3d.txt dataimg13826.jpeg batch 20 from 625.0
# 400
# 0.78125 0.2109375 0.21484375
# condcords19991_3d.txt dataimg19991.jpeg batch 20 from 625.0
# 400
# 0.78125 0.111328125 0.166015625
# condcords17050_3d.txt dataimg17050.jpeg batch 20 from 625.0
# 400
# 0.78125 0.17578125 0.169921875
# condcords21651_3d.txt dataimg21651.jpeg batch 20 from 625.0
# 400
# 0.78125 0.11328125 0.076171875
# condcords17687_3d.txt dataimg17687.jpeg batch 20 from 625.0
# 400
# 0.78125 0.1328125 0.125
# condcords05620_3d.txt dataimg05620.jpeg batch 20 from 625.0
# 400
# 0.78125 0.2109375 0.1796875
# condcords11235_3d.txt dataimg11235.jpeg batch 20 from 625.0
# 400
# 0.78125 0.1328125 0.056640625
# condcords14603_3d.txt dataimg14603.jpeg batch 20 from 625.0
# 400
# 0.78125 0.21875 0.18359375
# condcords09782_3d.txt dataimg09782.jpeg batch 20 from 625.0
# 400
# 0.78125 0.197265625 0.19921875
# condcords24602_3d.txt dataimg24602.jpeg batch 20 from 625.0
# 400
# 0.78125 0.140625 0.025390625
# condcords11294_3d.txt dataimg11294.jpeg batch 20 from 625.0
# 400
# 0.78125 0.158203125 0.08984375
# condcords19282_3d.txt dataimg19282.jpeg batch 20 from 625.0
# 400
# 0.78125 0.138671875 0.1328125
# condcords20548_3d.txt dataimg20548.jpeg batch 21 from 625.0
# 400
# 0.78125 0.1953125 0.025390625
# condcords20036_3d.txt dataimg20036.jpeg batch 21 from 625.0
# 400
# 0.78125 0.142578125 0.013671875
# condcords18323_3d.txt dataimg18323.jpeg batch 21 from 625.0
# 400
# 0.78125 0.177734375 0.18359375
# condcords21850_3d.txt dataimg21850.jpeg batch 21 from 625.0
# 400
# 0.78125 0.134765625 0.140625
# condcords20140_3d.txt dataimg20140.jpeg batch 21 from 625.0
# 400
# 0.78125 0.171875 0.05078125
# condcords08113_3d.txt dataimg08113.jpeg batch 21 from 625.0
# 400
# 0.78125 0.208984375 0.013671875
# condcords25984_3d.txt dataimg25984.jpeg batch 21 from 625.0
# 400
# 0.78125 0.12109375 0.064453125
# condcords06671_3d.txt dataimg06671.jpeg batch 21 from 625.0
# 400
# 0.78125 0.185546875 0.12890625
# condcords15877_3d.txt dataimg15877.jpeg batch 21 from 625.0
# 400
# 0.78125 0.197265625 0.0
# condcords04982_3d.txt dataimg04982.jpeg batch 21 from 625.0
# 400
# 0.78125 0.15234375 0.142578125
# condcords17519_3d.txt dataimg17519.jpeg batch 21 from 625.0
# 400
# 0.78125 0.189453125 0.111328125
# condcords05851_3d.txt dataimg05851.jpeg batch 21 from 625.0
# 400
# 0.78125 0.169921875 0.005859375
# condcords15861_3d.txt dataimg15861.jpeg batch 21 from 625.0
# 400
# 0.78125 0.20703125 0.0859375
# condcords20520_3d.txt dataimg20520.jpeg batch 21 from 625.0
# 400
# 0.78125 0.21484375 0.2109375
# condcords01932_3d.txt dataimg01932.jpeg batch 21 from 625.0
# 400
# 0.78125 0.162109375 0.140625
# condcords23557_3d.txt dataimg23557.jpeg batch 21 from 625.0
# 400
# 0.78125 0.146484375 0.1015625
# condcords06752_3d.txt dataimg06752.jpeg batch 22 from 625.0
# 400
# 0.78125 0.1953125 0.126953125
# condcords17535_3d.txt dataimg17535.jpeg batch 22 from 625.0
# 400
# 0.78125 0.140625 0.083984375
# condcords02886_3d.txt dataimg02886.jpeg batch 22 from 625.0
# 400
# 0.78125 0.1875 0.193359375
# condcords05918_3d.txt dataimg05918.jpeg batch 22 from 625.0
# 400
# 0.78125 0.13671875 0.166015625
# condcords09754_3d.txt dataimg09754.jpeg batch 22 from 625.0
# 400
# 0.78125 0.146484375 0.044921875
# condcords19405_3d.txt dataimg19405.jpeg batch 22 from 625.0
# 400
# 0.78125 0.1328125 0.0859375
# condcords04218_3d.txt dataimg04218.jpeg batch 22 from 625.0
# 400
# 0.78125 0.1171875 0.0390625
# condcords21149_3d.txt dataimg21149.jpeg batch 22 from 625.0
# 400
# 0.78125 0.16015625 0.08203125
# condcords18542_3d.txt dataimg18542.jpeg batch 22 from 625.0
# 400
# 0.78125 0.15234375 0.15625
# condcords04650_3d.txt dataimg04650.jpeg batch 22 from 625.0
# 400
# 0.78125 0.16015625 0.111328125
# condcords24928_3d.txt dataimg24928.jpeg batch 22 from 625.0
# 400
# 0.78125 0.2109375 0.0078125
# condcords13945_3d.txt dataimg13945.jpeg batch 22 from 625.0
# 400
# 0.78125 0.138671875 0.181640625
# condcords16437_3d.txt dataimg16437.jpeg batch 22 from 625.0
# 400
# 0.78125 0.16015625 0.173828125
# condcords17281_3d.txt dataimg17281.jpeg batch 22 from 625.0
# 400
# 0.78125 0.138671875 0.009765625
# condcords05828_3d.txt dataimg05828.jpeg batch 22 from 625.0
# 400
# 0.78125 0.205078125 0.138671875
# condcords15160_3d.txt dataimg15160.jpeg batch 22 from 625.0
# 400
# 0.78125 0.169921875 0.005859375
# condcords25129_3d.txt dataimg25129.jpeg batch 23 from 625.0
# 400
# 0.78125 0.138671875 0.193359375
# condcords01704_3d.txt dataimg01704.jpeg batch 23 from 625.0
# 400
# 0.78125 0.14453125 0.078125
# condcords14737_3d.txt dataimg14737.jpeg batch 23 from 625.0
# 400
# 0.78125 0.169921875 0.1796875
# condcords09249_3d.txt dataimg09249.jpeg batch 23 from 625.0
# 400
# 0.78125 0.19140625 0.015625
# condcords09930_3d.txt dataimg09930.jpeg batch 23 from 625.0
# 400
# 0.78125 0.173828125 0.0625
# condcords13799_3d.txt dataimg13799.jpeg batch 23 from 625.0
# 400
# 0.78125 0.21484375 0.1171875
# condcords03561_3d.txt dataimg03561.jpeg batch 23 from 625.0
# 400
# 0.78125 0.158203125 0.078125
# condcords24597_3d.txt dataimg24597.jpeg batch 23 from 625.0
# 400
# 0.78125 0.14453125 0.087890625
# condcords22858_3d.txt dataimg22858.jpeg batch 23 from 625.0
# 400
# 0.78125 0.18359375 0.146484375
# condcords05442_3d.txt dataimg05442.jpeg batch 23 from 625.0
# 400
# 0.78125 0.203125 0.16015625
# condcords24350_3d.txt dataimg24350.jpeg batch 23 from 625.0
# 400
# 0.78125 0.138671875 0.103515625
# condcords15446_3d.txt dataimg15446.jpeg batch 23 from 625.0
# 400
# 0.78125 0.126953125 0.0390625
# condcords20668_3d.txt dataimg20668.jpeg batch 23 from 625.0
# 400
# 0.78125 0.130859375 0.017578125
# condcords01723_3d.txt dataimg01723.jpeg batch 23 from 625.0
# 400
# 0.78125 0.115234375 0.04296875
# condcords19439_3d.txt dataimg19439.jpeg batch 23 from 625.0
# 400
# 0.78125 0.18359375 0.169921875
# condcords08355_3d.txt dataimg08355.jpeg batch 23 from 625.0
# 400
# 0.78125 0.13671875 0.2109375
# condcords05180_3d.txt dataimg05180.jpeg batch 24 from 625.0
# 400
# 0.78125 0.15234375 0.0546875
# condcords19934_3d.txt dataimg19934.jpeg batch 24 from 625.0
# 400
# 0.78125 0.21875 0.095703125
# condcords04865_3d.txt dataimg04865.jpeg batch 24 from 625.0
# 400
# 0.78125 0.158203125 0.02734375
# condcords10775_3d.txt dataimg10775.jpeg batch 24 from 625.0
# 400
# 0.78125 0.169921875 0.173828125
# condcords22324_3d.txt dataimg22324.jpeg batch 24 from 625.0
# 400
# 0.78125 0.171875 0.216796875
# condcords22748_3d.txt dataimg22748.jpeg batch 24 from 625.0
# 400
# 0.78125 0.15234375 0.181640625
# condcords08673_3d.txt dataimg08673.jpeg batch 24 from 625.0
# 400
# 0.78125 0.1953125 0.09375
# condcords05327_3d.txt dataimg05327.jpeg batch 24 from 625.0
# 400
# 0.78125 0.1640625 0.05078125
# condcords20157_3d.txt dataimg20157.jpeg batch 24 from 625.0
# 400
# 0.78125 0.125 0.17578125
# condcords14323_3d.txt dataimg14323.jpeg batch 24 from 625.0
# 400
# 0.78125 0.212890625 0.09375
# condcords26074_3d.txt dataimg26074.jpeg batch 24 from 625.0
# 400
# 0.78125 0.150390625 0.15625
# condcords22891_3d.txt dataimg22891.jpeg batch 24 from 625.0
# 400
# 0.78125 0.130859375 0.21875
# condcords25306_3d.txt dataimg25306.jpeg batch 24 from 625.0
# 400
# 0.78125 0.13671875 0.21484375
# condcords16166_3d.txt dataimg16166.jpeg batch 24 from 625.0
# 400
# 0.78125 0.1171875 0.033203125
# condcords03788_3d.txt dataimg03788.jpeg batch 24 from 625.0
# 400
# 0.78125 0.193359375 0.080078125
# condcords03637_3d.txt dataimg03637.jpeg batch 24 from 625.0
# 400
# 0.78125 0.119140625 0.138671875
# condcords14541_3d.txt dataimg14541.jpeg batch 25 from 625.0
# 400
# 0.78125 0.201171875 0.197265625
# condcords06485_3d.txt dataimg06485.jpeg batch 25 from 625.0
# 400
# 0.78125 0.15234375 0.107421875
# condcords22369_3d.txt dataimg22369.jpeg batch 25 from 625.0
# 400
# 0.78125 0.119140625 0.212890625
# condcords22044_3d.txt dataimg22044.jpeg batch 25 from 625.0
# 400
# 0.78125 0.1640625 0.0234375
# condcords02344_3d.txt dataimg02344.jpeg batch 25 from 625.0
# 400
# 0.78125 0.212890625 0.134765625
# condcords21909_3d.txt dataimg21909.jpeg batch 25 from 625.0
# 400
# 0.78125 0.189453125 0.091796875
# condcords09477_3d.txt dataimg09477.jpeg batch 25 from 625.0
# 400
# 0.78125 0.173828125 0.126953125
# condcords06404_3d.txt dataimg06404.jpeg batch 25 from 625.0
# 400
# 0.78125 0.203125 0.03125
# condcords12475_3d.txt dataimg12475.jpeg batch 25 from 625.0
# 400
# 0.78125 0.15234375 0.0703125
# condcords03997_3d.txt dataimg03997.jpeg batch 25 from 625.0
# 400
# 0.78125 0.208984375 0.037109375
# condcords13235_3d.txt dataimg13235.jpeg batch 25 from 625.0
# 400
# 0.78125 0.125 0.048828125
# condcords12742_3d.txt dataimg12742.jpeg batch 25 from 625.0
# 400
# 0.78125 0.146484375 0.041015625
# condcords24301_3d.txt dataimg24301.jpeg batch 25 from 625.0
# 400
# 0.78125 0.18359375 0.18359375
# condcords00855_3d.txt dataimg00855.jpeg batch 25 from 625.0
# 400
# 0.78125 0.158203125 0.150390625
# condcords00197_3d.txt dataimg00197.jpeg batch 25 from 625.0
# 400
# 0.78125 0.171875 0.12109375
# condcords01233_3d.txt dataimg01233.jpeg batch 25 from 625.0
# 400
# 0.78125 0.177734375 0.076171875
# condcords08663_3d.txt dataimg08663.jpeg batch 26 from 625.0
# 400
# 0.78125 0.171875 0.111328125
# condcords22115_3d.txt dataimg22115.jpeg batch 26 from 625.0
# 400
# 0.78125 0.162109375 0.072265625
# condcords00108_3d.txt dataimg00108.jpeg batch 26 from 625.0
# 400
# 0.78125 0.13671875 0.068359375
# condcords00879_3d.txt dataimg00879.jpeg batch 26 from 625.0
# 400
# 0.78125 0.20703125 0.029296875
# condcords17900_3d.txt dataimg17900.jpeg batch 26 from 625.0
# 400
# 0.78125 0.185546875 0.046875
# condcords18029_3d.txt dataimg18029.jpeg batch 26 from 625.0
# 400
# 0.78125 0.19921875 0.107421875
# condcords17937_3d.txt dataimg17937.jpeg batch 26 from 625.0
# 400
# 0.78125 0.177734375 0.203125
# condcords10850_3d.txt dataimg10850.jpeg batch 26 from 625.0
# 400
# 0.78125 0.17578125 0.041015625
# condcords03945_3d.txt dataimg03945.jpeg batch 26 from 625.0
# 400
# 0.78125 0.201171875 0.14453125
# condcords15443_3d.txt dataimg15443.jpeg batch 26 from 625.0
# 400
# 0.78125 0.1796875 0.044921875
# condcords24261_3d.txt dataimg24261.jpeg batch 26 from 625.0
# 400
# 0.78125 0.205078125 0.056640625
# condcords15183_3d.txt dataimg15183.jpeg batch 26 from 625.0
# 400
# 0.78125 0.1796875 0.177734375
# condcords14762_3d.txt dataimg14762.jpeg batch 26 from 625.0
# 400
# 0.78125 0.16015625 0.130859375
# condcords03053_3d.txt dataimg03053.jpeg batch 26 from 625.0
# 400
# 0.78125 0.109375 0.177734375
# condcords17484_3d.txt dataimg17484.jpeg batch 26 from 625.0
# 400
# 0.78125 0.212890625 0.181640625
# condcords18866_3d.txt dataimg18866.jpeg batch 26 from 625.0
# 400
# 0.78125 0.208984375 0.0703125
# condcords15097_3d.txt dataimg15097.jpeg batch 27 from 625.0
# 400
# 0.78125 0.13671875 0.111328125
# condcords12689_3d.txt dataimg12689.jpeg batch 27 from 625.0
# 400
# 0.78125 0.203125 0.123046875
# condcords18188_3d.txt dataimg18188.jpeg batch 27 from 625.0
# 400
# 0.78125 0.193359375 0.017578125
# condcords15582_3d.txt dataimg15582.jpeg batch 27 from 625.0
# 400
# 0.78125 0.119140625 0.1796875
# condcords16968_3d.txt dataimg16968.jpeg batch 27 from 625.0
# 400
# 0.78125 0.21875 0.2109375
# condcords21597_3d.txt dataimg21597.jpeg batch 27 from 625.0
# 400
# 0.78125 0.21875 0.017578125
# condcords23892_3d.txt dataimg23892.jpeg batch 27 from 625.0
# 400
# 0.78125 0.203125 0.171875
# condcords18408_3d.txt dataimg18408.jpeg batch 27 from 625.0
# 400
# 0.78125 0.12890625 0.1953125
# condcords13081_3d.txt dataimg13081.jpeg batch 27 from 625.0
# 400
# 0.78125 0.1328125 0.0703125
# condcords06829_3d.txt dataimg06829.jpeg batch 27 from 625.0
# 400
# 0.78125 0.216796875 0.193359375
# condcords06581_3d.txt dataimg06581.jpeg batch 27 from 625.0
# 400
# 0.78125 0.173828125 0.126953125
# condcords10837_3d.txt dataimg10837.jpeg batch 27 from 625.0
# 400
# 0.78125 0.146484375 0.109375
# condcords22606_3d.txt dataimg22606.jpeg batch 27 from 625.0
# 400
# 0.78125 0.20703125 0.009765625
# condcords05443_3d.txt dataimg05443.jpeg batch 27 from 625.0
# 400
# 0.78125 0.134765625 0.1015625
# condcords26689_3d.txt dataimg26689.jpeg batch 27 from 625.0
# 400
# 0.78125 0.185546875 0.1875
# condcords16686_3d.txt dataimg16686.jpeg batch 27 from 625.0
# 400
# 0.78125 0.203125 0.10546875
# condcords19578_3d.txt dataimg19578.jpeg batch 28 from 625.0
# 400
# 0.78125 0.16796875 0.17578125
# condcords24639_3d.txt dataimg24639.jpeg batch 28 from 625.0
# 400
# 0.78125 0.203125 0.0234375
# condcords17974_3d.txt dataimg17974.jpeg batch 28 from 625.0
# 400
# 0.78125 0.18359375 0.126953125
# condcords17988_3d.txt dataimg17988.jpeg batch 28 from 625.0
# 400
# 0.78125 0.154296875 0.169921875
# condcords02899_3d.txt dataimg02899.jpeg batch 28 from 625.0
# 400
# 0.78125 0.154296875 0.12109375
# condcords02130_3d.txt dataimg02130.jpeg batch 28 from 625.0
# 400
# 0.78125 0.146484375 0.16015625
# condcords19847_3d.txt dataimg19847.jpeg batch 28 from 625.0
# 400
# 0.78125 0.1796875 0.060546875
# condcords18369_3d.txt dataimg18369.jpeg batch 28 from 625.0
# 400
# 0.78125 0.189453125 0.181640625
# condcords25327_3d.txt dataimg25327.jpeg batch 28 from 625.0
# 400
# 0.78125 0.177734375 0.138671875
# condcords10065_3d.txt dataimg10065.jpeg batch 28 from 625.0
# 400
# 0.78125 0.21484375 0.064453125
# condcords18735_3d.txt dataimg18735.jpeg batch 28 from 625.0
# 400
# 0.78125 0.15625 0.048828125
# condcords05761_3d.txt dataimg05761.jpeg batch 28 from 625.0
# 400
# 0.78125 0.166015625 0.21484375
# condcords25187_3d.txt dataimg25187.jpeg batch 28 from 625.0
# 400
# 0.78125 0.185546875 0.07421875
# condcords04829_3d.txt dataimg04829.jpeg batch 28 from 625.0
# 400
# 0.78125 0.162109375 0.16796875
# condcords07260_3d.txt dataimg07260.jpeg batch 28 from 625.0
# 400
# 0.78125 0.138671875 0.126953125
# condcords24847_3d.txt dataimg24847.jpeg batch 28 from 625.0
# 400
# 0.78125 0.162109375 0.091796875
# condcords22952_3d.txt dataimg22952.jpeg batch 29 from 625.0
# 400
# 0.78125 0.111328125 0.146484375
# condcords01875_3d.txt dataimg01875.jpeg batch 29 from 625.0
# 400
# 0.78125 0.177734375 0.171875
# condcords15200_3d.txt dataimg15200.jpeg batch 29 from 625.0
# 400
# 0.78125 0.125 0.048828125
# condcords17768_3d.txt dataimg17768.jpeg batch 29 from 625.0
# 400
# 0.78125 0.1875 0.205078125
# condcords06365_3d.txt dataimg06365.jpeg batch 29 from 625.0
# 400
# 0.78125 0.12109375 0.1640625
# condcords07268_3d.txt dataimg07268.jpeg batch 29 from 625.0
# 400
# 0.78125 0.109375 0.181640625
# condcords16756_3d.txt dataimg16756.jpeg batch 29 from 625.0
# 400
# 0.78125 0.18359375 0.103515625
# condcords15453_3d.txt dataimg15453.jpeg batch 29 from 625.0
# 400
# 0.78125 0.11328125 0.02734375
# condcords03859_3d.txt dataimg03859.jpeg batch 29 from 625.0
# 400
# 0.78125 0.166015625 0.193359375
# condcords13772_3d.txt dataimg13772.jpeg batch 29 from 625.0
# 400
# 0.78125 0.205078125 0.001953125
# condcords22937_3d.txt dataimg22937.jpeg batch 29 from 625.0
# 400
# 0.78125 0.1328125 0.197265625
# condcords16172_3d.txt dataimg16172.jpeg batch 29 from 625.0
# 400
# 0.78125 0.21484375 0.0546875
# condcords02372_3d.txt dataimg02372.jpeg batch 29 from 625.0
# 400
# 0.78125 0.15234375 0.08984375
# condcords00580_3d.txt dataimg00580.jpeg batch 29 from 625.0
# 400
# 0.78125 0.189453125 0.177734375
# condcords16006_3d.txt dataimg16006.jpeg batch 29 from 625.0
# 400
# 0.78125 0.193359375 0.134765625
# condcords24740_3d.txt dataimg24740.jpeg batch 29 from 625.0
# 400
# 0.78125 0.181640625 0.1171875
# condcords05065_3d.txt dataimg05065.jpeg batch 30 from 625.0
# 400
# 0.78125 0.193359375 0.150390625
# condcords13994_3d.txt dataimg13994.jpeg batch 30 from 625.0
# 400
# 0.78125 0.189453125 0.078125
# condcords23057_3d.txt dataimg23057.jpeg batch 30 from 625.0
# 400
# 0.78125 0.134765625 0.015625
# condcords01824_3d.txt dataimg01824.jpeg batch 30 from 625.0
# 400
# 0.78125 0.12109375 0.01171875
# condcords19234_3d.txt dataimg19234.jpeg batch 30 from 625.0
# 400
# 0.78125 0.171875 0.083984375
# condcords20920_3d.txt dataimg20920.jpeg batch 30 from 625.0
# 400
# 0.78125 0.21484375 0.044921875
# condcords26058_3d.txt dataimg26058.jpeg batch 30 from 625.0
# 400
# 0.78125 0.142578125 0.146484375
# condcords08633_3d.txt dataimg08633.jpeg batch 30 from 625.0
# 400
# 0.78125 0.20703125 0.138671875
# condcords06291_3d.txt dataimg06291.jpeg batch 30 from 625.0
# 400
# 0.78125 0.134765625 0.1640625
# condcords19201_3d.txt dataimg19201.jpeg batch 30 from 625.0
# 400
# 0.78125 0.1328125 0.0390625
# condcords13220_3d.txt dataimg13220.jpeg batch 30 from 625.0
# 400
# 0.78125 0.2109375 0.095703125
# condcords00257_3d.txt dataimg00257.jpeg batch 30 from 625.0
# 400
# 0.78125 0.1953125 0.076171875
# condcords06548_3d.txt dataimg06548.jpeg batch 30 from 625.0
# 400
# 0.78125 0.150390625 0.060546875
# condcords16094_3d.txt dataimg16094.jpeg batch 30 from 625.0
# 400
# 0.78125 0.21875 0.09765625
# condcords09551_3d.txt dataimg09551.jpeg batch 30 from 625.0
# 400
# 0.78125 0.138671875 0.087890625
# condcords19017_3d.txt dataimg19017.jpeg batch 30 from 625.0
# 400
# 0.78125 0.19140625 0.09765625
# condcords26559_3d.txt dataimg26559.jpeg batch 31 from 625.0
# 400
# 0.78125 0.216796875 0.1484375
# condcords08569_3d.txt dataimg08569.jpeg batch 31 from 625.0
# 400
# 0.78125 0.162109375 0.025390625
# condcords17077_3d.txt dataimg17077.jpeg batch 31 from 625.0
# 400
# 0.78125 0.13671875 0.1875
# condcords24454_3d.txt dataimg24454.jpeg batch 31 from 625.0
# 400
# 0.78125 0.12109375 0.146484375
# condcords06825_3d.txt dataimg06825.jpeg batch 31 from 625.0
# 400
# 0.78125 0.1796875 0.060546875
# condcords23136_3d.txt dataimg23136.jpeg batch 31 from 625.0
# 400
# 0.78125 0.16796875 0.029296875
# condcords18996_3d.txt dataimg18996.jpeg batch 31 from 625.0
# 400
# 0.78125 0.216796875 0.1875
# condcords17061_3d.txt dataimg17061.jpeg batch 31 from 625.0
# 400
# 0.78125 0.115234375 0.1484375
# condcords04369_3d.txt dataimg04369.jpeg batch 31 from 625.0
# 400
# 0.78125 0.2109375 0.02734375
# condcords22659_3d.txt dataimg22659.jpeg batch 31 from 625.0
# 400
# 0.78125 0.216796875 0.146484375
# condcords22931_3d.txt dataimg22931.jpeg batch 31 from 625.0
# 400
# 0.78125 0.1640625 0.044921875
# condcords07177_3d.txt dataimg07177.jpeg batch 31 from 625.0
# 400
# 0.78125 0.14453125 0.0859375
# condcords05103_3d.txt dataimg05103.jpeg batch 31 from 625.0
# 400
# 0.78125 0.1875 0.10546875
# condcords15018_3d.txt dataimg15018.jpeg batch 31 from 625.0
# 400
# 0.78125 0.109375 0.05859375
# condcords22664_3d.txt dataimg22664.jpeg batch 31 from 625.0
# 400
# 0.78125 0.158203125 0.0625
# condcords25050_3d.txt dataimg25050.jpeg batch 31 from 625.0
# 400
# 0.78125 0.15625 0.0625
# condcords02583_3d.txt dataimg02583.jpeg batch 32 from 625.0
# 400
# 0.78125 0.201171875 0.0
# condcords23477_3d.txt dataimg23477.jpeg batch 32 from 625.0
# 400
# 0.78125 0.201171875 0.072265625
# condcords25719_3d.txt dataimg25719.jpeg batch 32 from 625.0
# 400
# 0.78125 0.138671875 0.001953125
# condcords14874_3d.txt dataimg14874.jpeg batch 32 from 625.0
# 400
# 0.78125 0.212890625 0.09375
# condcords04818_3d.txt dataimg04818.jpeg batch 32 from 625.0
# 400
# 0.78125 0.17578125 0.09765625
# condcords25405_3d.txt dataimg25405.jpeg batch 32 from 625.0
# 400
# 0.78125 0.17578125 0.037109375
# condcords15307_3d.txt dataimg15307.jpeg batch 32 from 625.0
# 400
# 0.78125 0.109375 0.12109375
# condcords26405_3d.txt dataimg26405.jpeg batch 32 from 625.0
# 400
# 0.78125 0.1328125 0.0390625
# condcords11717_3d.txt dataimg11717.jpeg batch 32 from 625.0
# 400
# 0.78125 0.1171875 0.0234375
# condcords16510_3d.txt dataimg16510.jpeg batch 32 from 625.0
# 400
# 0.78125 0.109375 0.046875
# condcords09483_3d.txt dataimg09483.jpeg batch 32 from 625.0
# 400
# 0.78125 0.21484375 0.16796875
# condcords09858_3d.txt dataimg09858.jpeg batch 32 from 625.0
# 400
# 0.78125 0.146484375 0.091796875
# condcords03144_3d.txt dataimg03144.jpeg batch 32 from 625.0
# 400
# 0.78125 0.119140625 0.201171875
# condcords15785_3d.txt dataimg15785.jpeg batch 32 from 625.0
# 400
# 0.78125 0.20703125 0.029296875
# condcords26658_3d.txt dataimg26658.jpeg batch 32 from 625.0
# 400
# 0.78125 0.12109375 0.107421875
# condcords16753_3d.txt dataimg16753.jpeg batch 32 from 625.0
# 400
# 0.78125 0.21875 0.015625
# ...
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# torch.Size([16, 3, 400, 400]) torch.Size([16, 68, 3])
# devise is:  cuda:0

# %%
train[0][0].shape

# %%
mouth_pointlist = [44, 7, 33, 14, 2, 31, 49, 15, 42, 32, 9, 51, 38, 61,
    18, 23, 12, 47, 67, 1, 2]
mouth_boundaries = [7, 14, 15, 67]
eye_L_pointlist = [62, 65, 0, 13, 34, 64]
eye_R_pointlist = [16, 36, 54, 55, 53, 63]
nose_pointlist = [5, 29, 51, 30, 4, 57]

eyes_corners = [53,36,62,13]

# %%
def coords_to_img(coordsbatch, idlist_list, imgsize, blobsize, bglevel):
    imglist = []
    for coords in coordsbatch:
        true_cord_list = []
        for idlist in idlist_list:
            midx = 0.0
            midy = 0.0
            for id in idlist:
                midx += coords[id][0]
                midy += coords[id][1]
            midx /= len(idlist)
            midy /= len(idlist)
            img = np.zeros((imgsize, imgsize), dtype=np.float32)
            x = int(midx * imgsize)
            y = int(midy * imgsize)
            true_cord_list.append(np.array([x, y]))

        for cord in true_cord_list:
            img[cord[1], cord[0]] = 15 * blobsize
        
        img = cv2.GaussianBlur(img, (351, 351), sigmaX=blobsize, borderType=cv2.BORDER_REPLICATE)
        
        for cord in true_cord_list:
            cv2.circle(img, (cord[0], cord[1]), 1, 6, -1)
        
    # img[y, x] = 15000
    # img = cv2.GaussianBlur(img, (351, 351), sigmaX=50, borderType=cv2.BORDER_REPLICATE)
    # cv2.circle(img, (x, y), 0, 6, -1)
    # img = cv2.GaussianBlur(img, (11, 11), sigmaX=1)

        img = cv2.GaussianBlur(img, (11, 11), sigmaX=2)
        img += bglevel
        imglist.append(torch.from_numpy(img).unsqueeze(0))
    return torch.stack(imglist)

# %%
def get_mean_coords(landmarks_list, tensor):
    x = torch.zeros(tensor.shape[0]).to(device)
    y = torch.zeros(tensor.shape[0]).to(device)
    for id in landmarks_list:
        x += tensor[:,id,0]
        y += tensor[:,id,1]
    x /= len(landmarks_list)
    y /= len(landmarks_list)
    return x, y

def lstolsofls(listoflist):
    newlist = []
    for listt in listoflist:
        newlist.append([listt])
    return newlist

# %%
class WMSELoss(nn.Module):
    def __init__(self,  device, l2_lambda = 0.001):
        super().__init__()
        self.device = device
        self.l2_lambda = l2_lambda
        
    def forward(self, x, y,weightmap, parameters = None):
        ls = ((x-y) * weightmap)**2
        sm = ls.sum() / (x.shape[0] * x.shape[1])
        if parameters is None:
            return sm
        
        pk = 0.0
        smp = 0.0
        if parameters is not None:
            for param in parameters:
                smp += (param**2).mean()
                pk += 1

        return sm + (smp / float(pk)) * self.l2_lambda

# %%
class CnnDetector(nn.Module):
    def __init__(self, device):
        super(CnnDetector, self).__init__()
        self.adpool = nn.AdaptiveAvgPool2d((128, 128)).to(device)
        self.pool = nn.MaxPool2d(2, 2).to(device)
        self.mid_depth = mid_depth = 7
        self.conv1 = nn.Conv2d(3, mid_depth, 7, padding = 3).to(device) 
        self.conv2 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv3 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv4 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv5 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv6 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv7 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv8 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv9 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv10 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv11 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv12 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv13 = nn.Conv2d(mid_depth, mid_depth, 3, padding = 1).to(device)
        self.conv14 = nn.Conv2d(mid_depth, 1, 3, padding = 1).to(device)
        fcsize = 200
        self.fc1 = nn.Linear(64 * 64, fcsize).to(device)
        self.fc2 = nn.Linear(fcsize, fcsize).to(device)
        self.fc3 = nn.Linear(fcsize, 64 * 64).to(device)
        self.act = nn.ReLU().to(device)

    def forward(self, x, fully_connected = False):
        # Input: [batch, 3, H, W]
        x = self.adpool(x)
        x1 = x.clone()
        x1 = x1.repeat(1, 3, 1, 1)[:, :self.mid_depth, :, :]
        x = self.act(self.conv1(x))
        x = self.pool(self.act(self.conv2(x)) + x1)
        x1 = x.clone()
        x = self.act(self.conv3(x))
        x = self.act(self.conv4(x)) + x1 # add skip connections (+x.copy()) if needed
        x1 = x.clone()
        x = self.act(self.conv5(x))
        x = self.act(self.conv6(x)) + x1 
        x1 = x.clone()
        x = self.act(self.conv7(x))
        x = self.act(self.conv8(x)) + x1
        x1 = x.clone()
        x = self.act(self.conv9(x))
        x = self.act(self.conv10(x)) + x1
        x1 = x.clone()
        x = self.act(self.conv11(x))
        x = self.act(self.conv12(x)) + x1
        x1 = x.clone()
        x = self.act(self.conv13(x))
        x = self.act(self.conv14(x)) + x1[:, :1, :, :] * 0.3
        # make freeze layers when needed amount of epochs exceed
        if fully_connected:
            x = x.view(-1, 64*64)
            x1 = x.clone()
            x = self.act(self.fc1(x))
            # x = self.act(self.fc2(x))
            x = self.act(self.fc3(x))
            x = (x + x1 * 0.3).view(-1, 64, 64).unsqueeze(1) 
        return x

# %%
model = CnnDetector(device).to(device)

criterion = WMSELoss(device)

criterion = nn.MSELoss().to

learning_rate = 0.01
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
learning_rate = 0.0001

# learning loop
epoch_loss = 0
for epoch in range(20):
    epoch_loss = 0
    step_loss = 0
    step_count = 0
    random.shuffle(train)
    for batch_idx, (inputs, answers) in enumerate(train):
        needshow = torch.tensor(False).to(device)
        if(batch_idx % 350 == 60):
           needshow = True

        inputs = inputs.to(device)
        answers = answers.to(device)

        fc = False

        outputs = model(inputs, fc)
        imganswers = coords_to_img(answers, [eye_L_pointlist, eye_R_pointlist], 64, 4, bglevel = 0).to(device)
        
        
        weightmap = coords_to_img(answers, [eye_L_pointlist,eye_R_pointlist, mouth_pointlist], 64, 15, bglevel = 0.15).to(device)
        if(needshow):
            #xshow = inputs[0].cpu().numpy()
            yshow = (outputs[0][0].cpu().detach().numpy() * 255.0).astype('float32')
            ansshow = (imganswers[0][0].cpu().detach().numpy() * 255.0).astype('float32')
            xshow = (inputs[0][0].cpu().detach().numpy() * 255.0).astype('float32')
            weightshow = (weightmap[0][0].cpu().detach().numpy() * 255.0).astype('float32')
            print(ansshow.max(), ansshow.min(), ansshow.mean(), ansshow.std())
            print(type(ansshow[0][0]))
            yshow = (yshow - yshow.min()) * 255 / (yshow.max() - yshow.min())
            ansshow = ansshow * 255 / ansshow.max()
            xshow = xshow * 255 / xshow.max()
            weightshow = weightshow * 255 / weightshow.max()
            pil_mod = Image.fromarray(yshow)
            pil_mod.show()
            # print(yshow.max(), yshow.min(), yshow.mean(), yshow.std())
            # pil_imagey = Image.fromarray(ansshow)
            # pil_imagey.show()
            # pil_weighshow = Image.fromarray(weightshow)
            # pil_weighshow.show()
        
        loss = criterion(outputs, imganswers)
        step_loss += loss
        step_count += 1
        if(step_count == 20):
            optimizer.zero_grad()
            step_loss.backward()
            optimizer.step()
            print(f'Batch {batch_idx}, Loss: {step_loss.item() / step_count:.5f}')
            step_count = 0
            step_loss = 0

        epoch_loss += loss.item() 
        

        if batch_idx == 1600:
            break
    
    #learning_rate /= 10.0
    #optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    print(f'shape {inputs.shape}, Epoch {epoch + 1}, Loss: {epoch_loss/len(train):.5f}')
# Out:
# Batch 19, Loss: 0.02311
# Batch 39, Loss: 0.02288
# Batch 59, Loss: 0.02286
# 374.38113 1.8050018e-21 10.843648 38.151836
# <class 'numpy.float32'>
# Batch 79, Loss: 0.02281
# Batch 99, Loss: 0.02413
# Batch 119, Loss: 0.02286
# Batch 139, Loss: 0.02283
# Batch 159, Loss: 0.02281
# Batch 179, Loss: 0.02284
# Batch 199, Loss: 0.02284
# Batch 219, Loss: 0.02284
# Batch 239, Loss: 0.02283
# Batch 259, Loss: 0.02281
# Batch 279, Loss: 0.02282
# Batch 299, Loss: 0.02284
# Batch 319, Loss: 0.02280
# Batch 339, Loss: 0.02282
# Batch 359, Loss: 0.02284
# Batch 379, Loss: 0.02283
# Batch 399, Loss: 0.02285
# 374.38095 4.635229e-25 10.844888 38.151066
# <class 'numpy.float32'>
# Batch 419, Loss: 0.02283
# Batch 439, Loss: 0.02281
# Batch 459, Loss: 0.02281
# Batch 479, Loss: 0.02283
# Batch 499, Loss: 0.02282
# Batch 519, Loss: 0.02284
# Batch 539, Loss: 0.02284
# Batch 559, Loss: 0.02284
# Batch 579, Loss: 0.02282
# Batch 599, Loss: 0.02285
# Batch 619, Loss: 0.02283
# shape torch.Size([16, 3, 400, 400]), Epoch 1, Loss: 0.02288
# Batch 19, Loss: 0.02279
# Batch 39, Loss: 0.02283
# Batch 59, Loss: 0.02281
# 374.38113 6.230985e-24 10.845624 38.151634
# <class 'numpy.float32'>
# Batch 79, Loss: 0.02281
# Batch 99, Loss: 0.02282
# Batch 119, Loss: 0.02282
# Batch 139, Loss: 0.02283
# Batch 159, Loss: 0.02281
# Batch 179, Loss: 0.02287
# Batch 199, Loss: 0.02282
# Batch 219, Loss: 0.02283
# Batch 239, Loss: 0.02286
# Batch 259, Loss: 0.02284
# Batch 279, Loss: 0.02283
# Batch 299, Loss: 0.02283
# Batch 319, Loss: 0.02284
# Batch 339, Loss: 0.02283
# Batch 359, Loss: 0.02281
# Batch 379, Loss: 0.02285
# Batch 399, Loss: 0.02285
# 374.38113 4.601862e-23 10.845624 38.151638
# <class 'numpy.float32'>
# Batch 419, Loss: 0.02282
# Batch 439, Loss: 0.02286
# Batch 459, Loss: 0.02282
# Batch 479, Loss: 0.02284
# Batch 499, Loss: 0.02282
# Batch 519, Loss: 0.02284
# Batch 539, Loss: 0.02281
# Batch 559, Loss: 0.02282
# Batch 579, Loss: 0.02282
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 20
#      16 answers = answers.to(device)
#      18 fc = False
# ---> 20 outputs = model(inputs, fc)
#      21 imganswers = coords_to_img(answers, [eye_L_pointlist, eye_R_pointlist], 64, 4, bglevel = 0).to(device)
#      24 weightmap = coords_to_img(answers, [eye_L_pointlist,eye_R_pointlist, mouth_pointlist], 64, 15, bglevel = 0.15).to(device)
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[30], line 42, in CnnDetector.forward(self, x, fully_connected)
#      40 xb = x2.clone()
#      41 x2 = self.act(self.conv32(x2))
# ---> 42 x2 = self.act(self.conv42(x2)) + 0.2 * xb[:, :1, :, :]
#      44 xb = xf.repeat(1, 3, 1, 1)[:, :self.mid_depth, :, :]
#      45 x3 = self.act(self.conv13(xf))
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\activation.py:103, in ReLU.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.relu(input, inplace=self.inplace)
#
# File c:\Users\evdra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:1500, in relu(input, inplace)
#    1498     result = torch.relu_(input)
#    1499 else:
# -> 1500     result = torch.relu(input)
#    1501 return result
#
# KeyboardInterrupt:

# %%
# testloop
criterion = SelectiveRMSELoss(eye_L_pointlist + eye_R_pointlist, False, device)
epoch_loss = 0
test = data_loader.load("I:/NSU/CV/tests/torch/data/test/coords",
                        "I:/NSU/CV/tests/torch/data/test/images",  
                        firstn = 2000, batchSize = 16, shuffle = True, displace = True, 
                        size = 400, show = False)
random.shuffle(test)

# %%
model

# %%
with torch.no_grad():
    for batch_idx, (inputs, answers) in enumerate(test):
        inputs = inputs.to(device)
        answers = answers.to(device)
        answers = scaler.transform(answers)
        outputs = model(inputs)
        outputs = scaler.inverse_transform(outputs)
        loss = criterion(outputs, answers)
        epoch_loss += loss.item()

    print(f'Test Loss: {epoch_loss/len(test):.4f}')

# %%
random.shuffle(test)
with torch.no_grad():
    inputs, answers = test[1]
    inputs = inputs.to(device)
    answers = answers.to(device)
    outputs = model(inputs)
    outputs = scaler.inverse_transform(outputs)
    # x_l, y_l = get_mean_coords(eye_L_pointlist, outputs)
    # x_r, y_r = get_mean_coords(eye_R_pointlist, outputs)
    # print(x_l[0], y_l[0], x_r[0], y_r[0])
    # outputs[0][1][0] = x_l[0]
    # outputs[0][1][1] = y_l[0]
    # outputs[0][2][0] = x_r[0]
    # outputs[0][2][1] = y_r[0]
    print(outputs.shape, answers.shape)
    img = modelutils.show_tensor(inputs[0], outputs[0])
    img.show()
    imgdlib = modelutils.show_tensor(inputs[0], answers[0])
    imgdlib.show()

# %%
#Save the model after training
torch.save(model.state_dict(), "eye_area_detector_multilfow.pth")

# %%
class mouthBoundDetector(nn.Module):
    def __init__(self, device):
        super(mouthBoundDetector, self).__init__()
        self.last_detector_size = 128 
        self.adpool = nn.AdaptiveAvgPool2d((128, 128)).to(device) 
        self.conv1 = nn.Conv2d(3, 6, 3, padding = 1).to(device)
        self.pool = nn.MaxPool2d(2, 2).to(device)
        self.conv2 = nn.Conv2d(6, 9, 3, padding = 1).to(device)
        self.conv3 = nn.Conv2d(9, 20, 3, padding = 1).to(device)
        self.conv4 = nn.Conv2d(20, self.last_detector_size, 3, padding = 1).to(device)
        fcsize = 256
        self.fc1 = nn.Linear(self.last_detector_size*16*16, fcsize).to(device)
        self.fc_list = []
        for i in range(3):
            self.fc_list.append(nn.Linear(fcsize, fcsize).to(device))
        self.prelast = nn.Linear(fcsize, fcsize).to(device)
        self.fc_last = nn.Linear(fcsize, 3 * 68).to(device)
        self.act = nn.ReLU().to(device)
        self.sigm = nn.Sigmoid().to(device)
    
    def forward(self, x):
        # Input: [batch, 3, H, W]
        x = self.adpool(x)
        x = self.pool(self.act(self.conv1(x)))
        x = self.pool(self.act(self.conv2(x)))
        x = self.act(self.conv3(x))  
        x = self.pool(self.act(self.conv4(x)))
        x = x.view(-1, self.last_detector_size*16*16)       
        x = self.act(self.fc1(x))
        for i in range(len(self.fc_list)):
            x = self.act(self.fc_list[i](x))
        x = self.act(self.prelast(x))
        x = self.fc_last(x)
        x = x.view(-1, 68, 3)
        return x

# %%
with torch.no_grad():
    inputs, answers = test[1]
    inputs = inputs.to(device)
    answers = answers.to(device)
    outputs = model(inputs)
    outputs = scaler.inverse_transform(outputs)
    print(outputs.shape, answers.shape)
    img = show_tensor(inputs[0], outputs[0])
    img.show()
    imgdlib = show_tensor(inputs[0], answers[0])
    imgdlib.show()
